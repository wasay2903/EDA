# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
path="Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=visa_df.select_dtypes(include="object").columns
num=visa_df.select_dtypes(exclude="object").columns
cat,num
# Out:
# (Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#         'requires_job_training', 'region_of_employment', 'unit_of_wage',
#         'full_time_position', 'case_status'],
#        dtype='object'),
#  Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object'))

# %% [markdown]
# **Prevailing wage**

# %% [markdown]
# - len
#
# - max
#
# - min
#
# - mean
#
# - median
#
# - 25p
#
# - 50p
#
# - 75p

# %%
wage_data=visa_df["prevailing_wage"]
len(wage_data)
# Out:
# 25480

# %%
min(wage_data)
# Out:
# 2.1367

# %%
wage_data.min()
# Out:
# 2.1367

# %%
np.min(wage_data)
# Out:
# 2.1367

# %%
wage_data=visa_df["prevailing_wage"]
min(wage_data),wage_data.min(),np.min(wage_data)
# Out:
# (2.1367, 2.1367, 2.1367)

# %%
max(wage_data),wage_data.max(),np.max(wage_data)
# Out:
# (319210.27, 319210.27, 319210.27)

# %%
np.mean(wage_data),wage_data.mean()
# Out:
# (np.float64(74455.81459209183), np.float64(74455.81459209183))

# %%
np.median(wage_data),wage_data.median()
# Out:
# (np.float64(70308.20999999999), 70308.20999999999)

# %% [markdown]
# **quantile-percentile**

# %%
p_25=np.percentile(wage_data,25)
p_25
# Out:
# np.float64(34015.479999999996)

# %%
p_50=np.percentile(wage_data,50)
p_50
# Out:
# np.float64(70308.20999999999)

# %%
p_75=np.percentile(wage_data,75)
p_75
# Out:
# np.float64(107735.51250000001)

# %%
q_25=np.quantile(wage_data,0.25)
q_25
# Out:
# np.float64(34015.479999999996)

# %%
q_50=np.quantile(wage_data,0.50)
q_50
# Out:
# np.float64(70308.20999999999)

# %%
q_75=np.quantile(wage_data,0.75)
q_75
# Out:
# np.float64(107735.51250000001)

# %%
wage_data=visa_df["prevailing_wage"]
wage_count=round(len(wage_data),2)
wage_min=round(wage_data.min(),2)
wage_mean=round(wage_data.mean(),2)
wage_median=round(wage_data.median(),2)
wage_25p=round(np.percentile(wage_data,25),2)
wage_50p=round(np.percentile(wage_data,50),2)
wage_75p=round(np.percentile(wage_data,75),2)
wage_max=round(wage_data.max(),2)
label=[wage_count,wage_min,wage_mean,wage_median,wage_25p,wage_50p,wage_75p,wage_max]
Id=["Count","Min","Mean","Median","25p","50p","75p","Max"]
df=pd.DataFrame(label,Id,columns=["prevailing_wage"])
df
# Out:
#         prevailing_wage
# Count          25480.00
# Min                2.14
# Mean           74455.81
# Median         70308.21
# 25p            34015.48
# 50p            70308.21
# 75p           107735.51
# Max           319210.27

# %%
big_list=[]
for i in num:
    data=visa_df[i]
    count=round(len(data),2)
    minimum=round(data.min(),2)
    mean=round(data.mean(),2)
    median=round(data.median(),2)
    twenty_five_p=round(np.percentile(data,25),2)
    fifty_p=round(np.percentile(data,50),2)
    seventy_five_p=round(np.percentile(data,75),2)
    maximum=round(data.max(),2)
    label=[count,minimum,mean,median,twenty_five_p,fifty_p,seventy_five_p,maximum]
    big_list.append(label)
    Id=["Count","Min","Mean","Median","25p","50p","75p","Max"]

pd.DataFrame(big_list,columns=Id,index=num).transpose()
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# Count          25480.00     25480.00         25480.00
# Min              -26.00      1800.00             2.14
# Mean            5667.04      1979.41         74455.81
# Median          2109.00      1997.00         70308.21
# 25p             1022.00      1976.00         34015.48
# 50p             2109.00      1997.00         70308.21
# 75p             3504.00      2005.00        107735.51
# Max           602069.00      2016.00        319210.27

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **percentile concept**

# %% [markdown]
# - 25p: 25 percentage of the data is less than or below 25p value
#
# - wage_25p :34015.48
#
#     - 25%(25480)=(25*25480)/100==>6370 applicatns
#     - 6370 applicants have salary less than 34015.48 dollors or ruppes

# %% [markdown]
# - 50p: 50 percentage of the data is less than or below 50p value
#
# - wage_25p :70308.21
#
#     - 50%(25480)=(50*25480)/100==>12740 applicatns
#     - 12740 applicants have salary less than 70308.21 dollors or ruppes

# %% [markdown]
# - 75p: 25 percentage of the data is less than or below 75p value
#
# - wage_75p :107735.51
#
#     - 75%(25480)=(25*25480)/100==>19110 applicatns
#     - 19110 applicants have salary less than 107735.21 dollors or ruppes

# %%
con=visa_df["prevailing_wage"]<wage_25p
visa_df[con]
len(visa_df[con])==(len(visa_df)*25)/100
# Out:
# True

# %%
con=visa_df["prevailing_wage"]<wage_50p
visa_df[con]
len(visa_df[con])==(len(visa_df)*50)/100
# Out:
# True

# %%
con=visa_df["prevailing_wage"]<wage_75p
visa_df[con]
len(visa_df[con])==(len(visa_df)*75)/100
# Out:
# True

# %% [markdown]
# **Emperical rule**
#
# - u-1sigma to u+1sigma 68%

# %%
wage_data=visa_df["prevailing_wage"]
mean=np.mean(wage_data)
standard_deviation=np.std(wage_data)
LB=mean-1*standard_deviation
UB=mean+1*standard_deviation
con1=visa_df["prevailing_wage"]>LB
con2=visa_df["prevailing_wage"]<UB
f_con=con1&con2
len(visa_df[f_con])
# Out:
# 17170

# %%
len(visa_df)*68/100
# Out:
# 17326.4

# %%
len(visa_df)*68/100==len(visa_df[f_con])
# Out:
# False

# %% [markdown]
# **Conclusion: Emperical rule failed wage data doesnot following Normal distribution**

# %% [markdown]
# **Histogram**

# %%
plt.hist(wage_data,bins=10)



# 2-5
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
inter_count,inter_vals,n=plt.hist(wage_data,bins=10)

# %%
inter_count
# Out:
# array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#          21.])

# %%
inter_vals
# Out:
# array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#        1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#        2.55368643e+05, 2.87289457e+05, 3.19210270e+05])

# %%
n
# Out:
# <BarContainer object of 10 artists>

# %%
lb=2.13670000e+00
ub=3.19229500e+04
con1=visa_df["prevailing_wage"]>=lb
con2=visa_df["prevailing_wage"]<ub
con=con1&con2
len(visa_df[con])
# Out:
# 6038

# %% [markdown]
# **outlier analysis**

# %% [markdown]
# - we understood imperical rule failed
#
# - then we ploted histogram
#
# - it is slightly deviated
#
# - so it is indicate the data has outliers
#
# - outliers can be show by **box plot**
#
#            Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
#                        |-----:-----|
#        o      |--------|     :     |--------|    o  o
#                        |-----:-----|
#      flier             <----------->            fliers
#                             IQR

# %% [markdown]
# $box plot$

# %%
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
plt.suptitle("histogram and box plot")
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.hist(wage_data)
plt.title("histogram_wage_data")
plt.subplot(1,2,2)
plt.boxplot(wage_data,vert=False)
plt.title("box_plot_wage_data")
plt.show()

# %% [markdown]
# **outliers data**

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=(q3-q1)
ub=q3+1.5*IQR
lb=q3-1.5*IQR
con1=wage_data>ub
con2=wage_data<lb
f_con1=con1|con2

con3=wage_data<ub
con4=wage_data>lb
f_con2=con3&con4
print(len(visa_df[f_con1]))
print(len(visa_df[f_con2]))
# Out:
# 427
# 25053
# 25480

# %%
len(visa_df[f_con1])+len(visa_df[f_con2])==25480
# Out:
# True

# %% [markdown]
# **fill the outliers**

# %% [markdown]
# - drop the outliers
#
# - fill with median
#
# - winsorization:fill with lb and ub

# %% [markdown]
# **fill with median**

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=(q3-q1)
ub=q3+1.5*IQR
lb=q3-1.5*IQR
con1=wage_data>ub
con2=wage_data<lb
con=con1|con2

outlier_df=visa_df[con]
outlier_df["prevailing_wage"].values
outliers=outlier_df["prevailing_wage"].values.tolist()
l=[]
wage_data=visa_df["prevailing_wage"]
wage_med=wage_data.median()
for values in wage_data:
    if values in outliers:
        l.append(wage_med)
    else:
        l.append(values)
visa_df["prevailing_wage1"]=l
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1).hist(visa_df["prevailing_wage1"])
plt.subplot(2,2,2).boxplot(visa_df["prevailing_wage1"],vert=False)
plt.subplot(2,2,3).hist(visa_df["prevailing_wage"])
plt.subplot(2,2,4).boxplot(visa_df["prevailing_wage"],vert=False)
plt.show()

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=(q3-q1)
ub=q3+1.5*IQR
lb=q3-1.5*IQR

wage_data=visa_df["prevailing_wage"]
visa_df["prevailing_wage2"]=wage_data.clip(lower=lb,upper=ub)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1).hist(visa_df["prevailing_wage2"])
plt.subplot(2,2,2).boxplot(visa_df["prevailing_wage2"],vert=False)
plt.subplot(2,2,3).hist(visa_df["prevailing_wage"])
plt.subplot(2,2,4).boxplot(visa_df["prevailing_wage"],vert=False)
plt.show()
